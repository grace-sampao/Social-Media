# %%
import environment
import importlib

importlib.reload(environment)

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_tavily import TavilyExtract
from langchain.agents import create_agent

# %%
# Initialize the llm
llm = ChatGoogleGenerativeAI(
  model="gemini-3.5-flash",
  api_key=environment.GEMINI_API_KEY,
  temperature=1.0,
  max_tokens=None,
  timeout=None,
  max_retries=2,
)

# Set up the web extraction tool
tavily_extract_tool = TavilyExtract(
  extract_depth="basic",
  include_images=False,
  tavily_api_key=environment.TAVILY_API_KEY,
  # format="text",
)

system_prompt = """
You are a skilled LinkedIn social media manager.
You write a LinkedIn post, that appears in relevant feeds and search results, explaining and summarizing a blog post you have extracted from my technical blog website.
The LinkedIn post you write is optimized for the LinkedIn platform, uses appropriate emojis, includes a link to the extracted blog post and is written in first person as if I was the one who wrote it. 
"""

url = "['https://grace-sampao.github.io/posts/building-llm-powered-applications-chapter-01/']"

# Build a smart LangChain agent & bind the web extraction tool
agent = create_agent(
  model=llm,
  tools=[tavily_extract_tool],
  system_prompt=system_prompt,
)

# %%
# Invocation
linkedin_post = agent.invoke(
  {"messages": url}
)

# %%
print(
  linkedin_post["messages"][-1].content[0]["text"]
)
# Out:
# 🚀 **Are we building resilient AI architectures, or are we just wrapping APIs?**
#
# With the explosive rise of Generative AI, it’s easy to get caught up in the magic of out-of-the-box models. But to transition from a software engineer using API wrappers to a true **AI Systems Architect**, we have to understand the mathematical and structural foundations under the hood.
#
# In my latest learning log, I dive deep into Chapter 1 of *“Building LLM Powered Applications”* by Valentina Alto! 📚
#
# Here is my TL;DR on the core concepts every developer should master to build robust AI systems:
#
# 🔹 **LLMs are Reasoning Engines, Not Just Text Generators**
# While traditional Natural Language Understanding (NLU) maps text to a predetermined set of rules, LLMs leverage transfer learning and massive parameters to infer patterns and dynamically predict the next best words.
#
# 🔹 **The Skyscraper Analogy (Scale & Adaptability)**
# Think of a neural network like a building. A small cottage has simple plumbing. A skyscraper has massively complex, integrated routing systems. In AI, this parameter scale is precisely what allows models to capture complex, non-linear relationships and generalize across multiple domains.
#
# 🔹 **The Essential Mathematics of AI**
# Behind every prompt and output lies pure math:
# * **Tokenization & Embedding:** Converting raw text into dense, high-dimensional vector representations (like the 1,536-dimension space used in state-of-the-art models).
# * **Backpropagation:** Adjusting artificial neural network weights using gradient descent to minimize errors.
# * **The Softmax Function:** Converting final vector representations into actual probability distributions to predict the next word.
# *(I even applied some of these mathematical fundamentals, specifically Bayes’ Theorem, to build a Naive Bayes movie recommendation engine! 🎬)*
#
# 🔹 **Moving Beyond API Wrappers**
# To build production-ready applications, understanding APIs isn't enough. We need to design advanced **Agentic Workflows**, secure **Retrieval-Augmented Generation (RAG)** systems, and know when to apply **Fine-Tuning** versus **Few-Shot Learning**.
#
# ---
#
# 🔄 **The Core LLM Pipeline:**
# `Raw Text` ➡️ `Tokenizer` ➡️ `Embeddings (Vectors)` ➡️ `Weights/Biases` ➡️ `Softmax` ➡️ `Output Probability`
#
# Want a deeper dive into the math, vectors, and architectural principles of LLMs?
#
# 👉 **Read the full blog post here:** https://grace-sampao.github.io/posts/building-llm-powered-applications-chapter-01/
#
# How are you transitioning your skills from basic API integration to deep AI engineering? Let's discuss in the comments! 👇
#
# #GenerativeAI #LLMs #MachineLearning #AIEngineering #SoftwareEngineering #DeepLearning #TechBlog #DataScience
