# %%
import environment
import importlib

importlib.reload(environment)

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_tavily import TavilyExtract
from langchain.agents import create_agent

# %%
# Initialize the llm
llm = ChatGoogleGenerativeAI(
  model="gemini-3.5-flash",
  api_key=environment.GEMINI_API_KEY,
  temperature=1.0,
  max_tokens=None,
  timeout=None,
  max_retries=2,
)

# Set up the web extraction tool
tavily_extract_tool = TavilyExtract(
  extract_depth="basic",
  include_images=False,
  tavily_api_key=environment.TAVILY_API_KEY,
  # format="text",
)

system_prompt = """
You are a skilled LinkedIn social media manager.
You write a LinkedIn post, that appears in relevant feeds and search results, explaining and summarizing a blog post you have extracted from my technical blog website.
The LinkedIn post you write is optimized for the LinkedIn platform, uses appropriate emojis, includes a link to the extracted blog post and is written in first person as if I was the one who wrote it. 
"""

url = "['https://grace-sampao.github.io/posts/building-llm-powered-applications-chapter-01/']"

# Build a smart LangChain agent & bind the web extraction tool
agent = create_agent(
  model=llm,
  tools=[tavily_extract_tool],
  system_prompt=system_prompt,
)

# %%
# Invocation
linkedin_post = agent.invoke(
  {"messages": url}
)

# %%
print(
  linkedin_post["messages"][-1].content[0]["text"]
)
# Out:
# Are you building AI applications by just wrapping APIs? It might be time to level up. 🚀
#
# To transition from a software engineer to a true **AI Systems Architect**, we need to deeply understand the mathematical and structural foundations beneath Large Language Models (LLMs). Without this baseline, our production-ready applications risk being built on a shaky foundation.
#
# In my latest learning log, I dive deep into Chapter 1 of Valentina Alto’s book, *"Building LLM Powered Applications"*.
#
# Here is a quick preview of the foundational concepts I break down:
#
# 🧠 **LLMs as Reasoning Engines:** Why Generative AI is a massive paradigm shift from traditional Natural Language Understanding (NLU).
# 🏙️ **The Skyscraper Analogy:** How scaling neural networks to billions of parameters unlocks exponential adaptability—much like how the complex internal routing (HVAC, plumbing, electrical) of a massive skyscraper behaves compared to a single-story house.
# 📐 **The Math Under the Hood:** How raw text is transformed into 1536-dimensional vector spaces using linear algebra, and how backpropagation updates model weights.
# 🛠️ **Going Beyond "Wrappers":** A look into critical evaluation metrics (like MMLU and HellaSwag) and advanced customization techniques like Few-Shot Learning, Retrieval-Augmented Generation (RAG), and Fine-Tuning.
#
# I also share how these core ML principles connect to hands-on projects, including a link to my own implementation of a Naive Bayes movie recommendation engine! 🎬
#
# 👉 Read the full breakdown on my blog: https://grace-sampao.github.io/posts/building-llm-powered-applications-chapter-01/
#
# What is your biggest challenge when moving from a quick LLM prototype to production-grade architecture? Let's discuss in the comments! 👇
#
# #GenerativeAI #LLMs #MachineLearning #AIEngineering #SoftwareDevelopment #NeuralNetworks #TechCommunity
